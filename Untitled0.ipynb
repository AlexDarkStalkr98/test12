# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive
# Out:
# /content/drive

# %%
# %cd MyDrive/test
# Out:
# /content/drive/MyDrive/test

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/test/.git/

# %%
# !git
